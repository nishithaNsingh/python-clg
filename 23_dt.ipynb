# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:\\Users\\Student\\Desktop\\20221CSD0069\\German_Credit_Card.csv")

# %%
df.head(10)
# Out:
#   checkin_acc  duration credit_history  amount savings_acc present_emp_since  \
# 0         A11         6            A34    1169         A65               A75
# 1         A12        48            A32    5951         A61               A73
# 2         A14        12            A34    2096         A61               A74
# 3         A11        42            A32    7882         A61               A74
# 4         A11        24            A33    4870         A61               A73
# 5         A14        36            A32    9055         A65               A73
# 6         A14        24            A32    2835         A63               A75
# 7         A12        36            A32    6948         A61               A73
# 8         A14        12            A32    3059         A64               A74
# 9         A12        30            A34    5234         A61               A71
#
#    inst_rate personal_status  residing_since  age inst_plans  num_credits  \
# 0          4             A93               4   67       A143            2
# 1          2             A92               2   22       A143            1
# 2          2             A93               3   49       A143            1
# 3          2             A93               4   45       A143            1
# 4          3             A93               4   53       A143            2
# 5          2             A93               4   35       A143            1
# 6          3             A93               4   53       A143            1
# 7          2             A93               2   35       A143            1
# 8          2             A91               4   61       A143            1
# 9          4             A94               2   28       A143            2
#
#     job  status
# 0  A173       0
# 1  A173       1
# 2  A172       0
# 3  A173       0
# 4  A173       1
# 5  A172       0
# 6  A173       0
# 7  A174       0
# 8  A172       0
# 9  A174       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   checkin_acc        1000 non-null   object
#  1   duration           1000 non-null   int64
#  2   credit_history     1000 non-null   object
#  3   amount             1000 non-null   int64
#  4   savings_acc        1000 non-null   object
#  5   present_emp_since  1000 non-null   object
#  6   inst_rate          1000 non-null   int64
#  7   personal_status    1000 non-null   object
#  8   residing_since     1000 non-null   int64
#  9   age                1000 non-null   int64
#  10  inst_plans         1000 non-null   object
#  11  num_credits        1000 non-null   int64
#  12  job                1000 non-null   object
#  13  status             1000 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#           duration        amount    inst_rate  residing_since          age  \
# count  1000.000000   1000.000000  1000.000000     1000.000000  1000.000000
# mean     20.903000   3271.258000     2.973000        2.845000    35.546000
# std      12.058814   2822.736876     1.118715        1.103718    11.375469
# min       4.000000    250.000000     1.000000        1.000000    19.000000
# 25%      12.000000   1365.500000     2.000000        2.000000    27.000000
# 50%      18.000000   2319.500000     3.000000        3.000000    33.000000
# 75%      24.000000   3972.250000     4.000000        4.000000    42.000000
# max      72.000000  18424.000000     4.000000        4.000000    75.000000
#
#        num_credits       status
# count  1000.000000  1000.000000
# mean      1.407000     0.300000
# std       0.577654     0.458487
# min       1.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     0.000000
# 75%       2.000000     1.000000
# max       4.000000     1.000000

# %%
df.iloc[2:4,2:4]
# Out:
#   credit_history  amount
# 2            A34    2096
# 3            A32    7882

# %%
df.iloc[:5,:7]
# Out:
#   checkin_acc  duration credit_history  amount savings_acc present_emp_since  \
# 0         A11         6            A34    1169         A65               A75
# 1         A12        48            A32    5951         A61               A73
# 2         A14        12            A34    2096         A61               A74
# 3         A11        42            A32    7882         A61               A74
# 4         A11        24            A33    4870         A61               A73
#
#    inst_rate
# 0          4
# 1          2
# 2          2
# 3          2
# 4          3

# %%
df.iloc[:5,0:]
# Out:
#   checkin_acc  duration credit_history  amount savings_acc present_emp_since  \
# 0         A11         6            A34    1169         A65               A75
# 1         A12        48            A32    5951         A61               A73
# 2         A14        12            A34    2096         A61               A74
# 3         A11        42            A32    7882         A61               A74
# 4         A11        24            A33    4870         A61               A73
#
#    inst_rate personal_status  residing_since  age inst_plans  num_credits  \
# 0          4             A93               4   67       A143            2
# 1          2             A92               2   22       A143            1
# 2          2             A93               3   49       A143            1
# 3          2             A93               4   45       A143            1
# 4          3             A93               4   53       A143            2
#
#     job  status
# 0  A173       0
# 1  A173       1
# 2  A172       0
# 3  A173       0
# 4  A173       1

# %%
df['checkin_acc'].unique()
# Out:
# array(['A11', 'A12', 'A14', 'A13'], dtype=object)

# %%
df['num_credits'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
x_features = list(df.columns)
x_features.remove('status')
encoded_df = pd.get_dummies(df[x_features],drop_first=True)
print(list(encoded_df.columns))
# Out:
# ['duration', 'amount', 'inst_rate', 'residing_since', 'age', 'num_credits', 'checkin_acc_A12', 'checkin_acc_A13', 'checkin_acc_A14', 'credit_history_A31', 'credit_history_A32', 'credit_history_A33', 'credit_history_A34', 'savings_acc_A62', 'savings_acc_A63', 'savings_acc_A64', 'savings_acc_A65', 'present_emp_since_A72', 'present_emp_since_A73', 'present_emp_since_A74', 'present_emp_since_A75', 'personal_status_A92', 'personal_status_A93', 'personal_status_A94', 'inst_plans_A142', 'inst_plans_A143', 'job_A172', 'job_A173', 'job_A174']

# %%
encoded_df.sum().count()
# Out:
# 29

# %%
encoded_df.isnull().count()
# Out:
# duration                 1000
# amount                   1000
# inst_rate                1000
# residing_since           1000
# age                      1000
# num_credits              1000
# checkin_acc_A12          1000
# checkin_acc_A13          1000
# checkin_acc_A14          1000
# credit_history_A31       1000
# credit_history_A32       1000
# credit_history_A33       1000
# credit_history_A34       1000
# savings_acc_A62          1000
# savings_acc_A63          1000
# savings_acc_A64          1000
# savings_acc_A65          1000
# present_emp_since_A72    1000
# present_emp_since_A73    1000
# present_emp_since_A74    1000
# present_emp_since_A75    1000
# personal_status_A92      1000
# personal_status_A93      1000
# personal_status_A94      1000
# inst_plans_A142          1000
# inst_plans_A143          1000
# job_A172                 1000
# job_A173                 1000
# job_A174                 1000
# dtype: int64

# %%
encoded_df.isnull().sum()
# Out:
# duration                 0
# amount                   0
# inst_rate                0
# residing_since           0
# age                      0
# num_credits              0
# checkin_acc_A12          0
# checkin_acc_A13          0
# checkin_acc_A14          0
# credit_history_A31       0
# credit_history_A32       0
# credit_history_A33       0
# credit_history_A34       0
# savings_acc_A62          0
# savings_acc_A63          0
# savings_acc_A64          0
# savings_acc_A65          0
# present_emp_since_A72    0
# present_emp_since_A73    0
# present_emp_since_A74    0
# present_emp_since_A75    0
# personal_status_A92      0
# personal_status_A93      0
# personal_status_A94      0
# inst_plans_A142          0
# inst_plans_A143          0
# job_A172                 0
# job_A173                 0
# job_A174                 0
# dtype: int64

# %%
x = encoded_df
y = df["status"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.7,random_state=42)

# %%
x_train.shape
# Out:
# (300, 29)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion = "gini", max_depth = 3)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
pred_y = clf.predict(x_test)

# %%
from sklearn import metrics
print("Confusion Matrix is\n",metrics.confusion_matrix(pred_y,y_test))
print("Accuracy is",metrics.accuracy_score(pred_y,y_test))
print("AUC Score is",metrics.roc_auc_score(pred_y,y_test))
# Out:
# Confusion Matrix is
#  [[377 107]
#  [115 101]]
# Accuracy is 0.6828571428571428
# AUC Score is 0.6232591062136517

# %%
# !pip install pydotplus
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydotplus in c:\users\student\appdata\roaming\python\python312\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\programdata\anaconda3\lib\site-packages (from pydotplus) (3.0.9)

# %%
from sklearn.tree import export_graphviz
import pydotplus as pdot
from IPython.display import Image
export_graphviz(clf,out_file = "tree.odt", feature_names = x_train.columns,filled = True)
graph = pdot.graphviz.graph_from_dot_file("tree.odt")
graph.write_jpg("tree.png")
Image(filename = "tree.png")
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[25], line 6
#       4 export_graphviz(clf,out_file = "tree.odt", feature_names = x_train.columns,filled = True)
#       5 graph = pdot.graphviz.graph_from_dot_file("tree.odt")
# ----> 6 graph.write_jpg("tree.png")
#       7 Image(filename = "tree.png")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found

# %%
# %pip install pydotplus
